# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From d:\Father's_Document\code\Projects\CustomerChurnPredcition\venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
#define the vocabulary 
vocab_size=10000

# %%
### One Hot Representation 
one_hot_repr=[one_hot(words,vocab_size) for words in sent]
one_hot_repr
# Out:
# [[5334, 6436, 5337, 9624],
#  [5334, 6436, 5337, 8333],
#  [5334, 7045, 5337, 9670],
#  [7664, 5451, 7940, 8871, 4620],
#  [7664, 5451, 7940, 8871, 6712],
#  [9813, 5334, 3685, 5337, 997],
#  [9115, 328, 624, 8871]]

# %%
#word embedding  Representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_len=8

# %%
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_len)
# embedded_docs=pad_sequences(one_hot_repr,padding='post',maxlen=sent_len)
print(embedded_docs)
# Out:
# [[   0    0    0    0 5334 6436 5337 9624]
#  [   0    0    0    0 5334 6436 5337 8333]
#  [   0    0    0    0 5334 7045 5337 9670]
#  [   0    0    0 7664 5451 7940 8871 4620]
#  [   0    0    0 7664 5451 7940 8871 6712]
#  [   0    0    0 9813 5334 3685 5337  997]
#  [   0    0    0    0 9115  328  624 8871]]

# %%
#feature representation
dim=10

# %%
model=Sequential()
model.add(Embedding(vocab_size,dim,input_length=sent_len))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From d:\Father's_Document\code\Projects\CustomerChurnPredcition\venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From d:\Father's_Document\code\Projects\CustomerChurnPredcition\venv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 86ms/step
# array([[[ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [-0.03632307,  0.02238481, -0.01155145, -0.04520991,
#           0.02116616,  0.0240126 ,  0.04362733,  0.02240721,
#           0.03452085,  0.01128527],
#         [-0.01327049,  0.00062784,  0.0371488 , -0.03466873,
#          -0.03611652,  0.01756997, -0.03329592, -0.00027301,
#          -0.03797637, -0.0412464 ],
#         [-0.02153742,  0.01453799, -0.03458333, -0.01842035,
#           0.04691168, -0.00245248,  0.02281087, -0.02179828,
#           0.0454965 , -0.0057093 ],
#         [-0.0493977 , -0.048146  , -0.04539922,  0.01558084,
#           0.02030021,  0.0393564 ,  0.02715829,  0.04936004,
#          -0.00837263,  0.03188236]],
#
#        [[ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [-0.03632307,  0.02238481, -0.01155145, -0.04520991,
#           0.02116616,  0.0240126 ,  0.04362733,  0.02240721,
#           0.03452085,  0.01128527],
#         [-0.01327049,  0.00062784,  0.0371488 , -0.03466873,
#          -0.03611652,  0.01756997, -0.03329592, -0.00027301,
#          -0.03797637, -0.0412464 ],
#         [-0.02153742,  0.01453799, -0.03458333, -0.01842035,
#           0.04691168, -0.00245248,  0.02281087, -0.02179828,
#           0.0454965 , -0.0057093 ],
#         [-0.04689832, -0.03280129, -0.02070795, -0.04755289,
#          -0.00926833,  0.02957683,  0.04221189,  0.03413567,
#          -0.02924546, -0.0122118 ]],
#
#        [[ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [-0.03632307,  0.02238481, -0.01155145, -0.04520991,
#           0.02116616,  0.0240126 ,  0.04362733,  0.02240721,
#           0.03452085,  0.01128527],
#         [ 0.04305501,  0.02519624,  0.04178388,  0.01063591,
#           0.0384464 , -0.0068532 ,  0.0305368 , -0.04966795,
#           0.03776957,  0.03667872],
#         [-0.02153742,  0.01453799, -0.03458333, -0.01842035,
#           0.04691168, -0.00245248,  0.02281087, -0.02179828,
#           0.0454965 , -0.0057093 ],
#         [-0.02548935, -0.01450988, -0.00292524, -0.02419729,
#           0.01616749, -0.03292654, -0.00667933, -0.01661605,
#          -0.00955693,  0.04562135]],
#
#        [[ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [-0.02797289,  0.04992778, -0.00977346,  0.04110911,
#           0.0184607 , -0.02996584,  0.04782026,  0.00654576,
#          -0.01076654, -0.04228402],
#         [ 0.02941317, -0.02072002,  0.00110141, -0.00946938,
#           0.03878323,  0.01318165, -0.0275044 , -0.01257533,
#           0.00592891,  0.04223186],
#         [-0.00385026,  0.04255389, -0.03747582, -0.03500174,
#          -0.00536776,  0.03645572, -0.01677696,  0.00613415,
#           0.01105238,  0.04683968],
#         [-0.0478835 , -0.02369707,  0.03875282,  0.01755704,
#          -0.03196508, -0.02945563,  0.00815333,  0.01303362,
#          -0.01648416, -0.03970517],
#         [-0.04368126, -0.0216569 ,  0.0064855 ,  0.00958444,
#          -0.02907305, -0.02846707, -0.03140017,  0.0092532 ,
#          -0.03983886, -0.00495319]],
#
#        [[ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [-0.02797289,  0.04992778, -0.00977346,  0.04110911,
#           0.0184607 , -0.02996584,  0.04782026,  0.00654576,
#          -0.01076654, -0.04228402],
#         [ 0.02941317, -0.02072002,  0.00110141, -0.00946938,
#           0.03878323,  0.01318165, -0.0275044 , -0.01257533,
#           0.00592891,  0.04223186],
#         [-0.00385026,  0.04255389, -0.03747582, -0.03500174,
#          -0.00536776,  0.03645572, -0.01677696,  0.00613415,
#           0.01105238,  0.04683968],
#         [-0.0478835 , -0.02369707,  0.03875282,  0.01755704,
#          -0.03196508, -0.02945563,  0.00815333,  0.01303362,
#          -0.01648416, -0.03970517],
#         [-0.00216329,  0.04610993, -0.00280885,  0.01800102,
#          -0.04453288,  0.03452827, -0.03565217, -0.01577286,
#          -0.03466277,  0.01455459]],
#
#        [[ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.03879802, -0.02296031,  0.01085211,  0.01331538,
#           0.01882938,  0.00554508,  0.01616066, -0.02160631,
#          -0.00386921,  0.01343234],
#         [-0.03632307,  0.02238481, -0.01155145, -0.04520991,
#           0.02116616,  0.0240126 ,  0.04362733,  0.02240721,
#           0.03452085,  0.01128527],
#         [ 0.01164443,  0.02633889,  0.02975787, -0.04124425,
#           0.03575449,  0.03084905,  0.03428188, -0.01721372,
#          -0.04504297,  0.02217683],
#         [-0.02153742,  0.01453799, -0.03458333, -0.01842035,
#           0.04691168, -0.00245248,  0.02281087, -0.02179828,
#           0.0454965 , -0.0057093 ],
#         [-0.01216283, -0.04629343,  0.0177936 ,  0.0371456 ,
#           0.02834852,  0.01530482,  0.03075439, -0.01956859,
#          -0.00494949, -0.04220752]],
#
#        [[ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [ 0.04788259, -0.02818277, -0.01253913,  0.03997859,
#          -0.03490133,  0.02902612,  0.02698771, -0.04037894,
#          -0.016551  , -0.01164677],
#         [-0.0440475 , -0.03935553, -0.01149547, -0.00519428,
#          -0.04766123, -0.0111982 ,  0.00825833, -0.00932237,
#           0.0099836 , -0.02856417],
#         [-0.03178573, -0.04809285,  0.0062508 ,  0.00298908,
#           0.00960799,  0.02496001,  0.00632267,  0.04437575,
#          -0.02858905, -0.03221879],
#         [ 0.01173707, -0.02567822,  0.01886517,  0.02747751,
#           0.02724177, -0.03869068, -0.01721536,  0.04890095,
#          -0.00072797,  0.02799674],
#         [-0.0478835 , -0.02369707,  0.03875282,  0.01755704,
#          -0.03196508, -0.02945563,  0.00815333,  0.01303362,
#          -0.01648416, -0.03970517]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 5334, 6436, 5337, 9624])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 16ms/step
# array([[ 0.04788259, -0.02818277, -0.01253913,  0.03997859, -0.03490133,
#          0.02902612,  0.02698771, -0.04037894, -0.016551  , -0.01164677],
#        [ 0.04788259, -0.02818277, -0.01253913,  0.03997859, -0.03490133,
#          0.02902612,  0.02698771, -0.04037894, -0.016551  , -0.01164677],
#        [ 0.04788259, -0.02818277, -0.01253913,  0.03997859, -0.03490133,
#          0.02902612,  0.02698771, -0.04037894, -0.016551  , -0.01164677],
#        [ 0.04788259, -0.02818277, -0.01253913,  0.03997859, -0.03490133,
#          0.02902612,  0.02698771, -0.04037894, -0.016551  , -0.01164677],
#        [-0.03632307,  0.02238481, -0.01155145, -0.04520991,  0.02116616,
#          0.0240126 ,  0.04362733,  0.02240721,  0.03452085,  0.01128527],
#        [-0.01327049,  0.00062784,  0.0371488 , -0.03466873, -0.03611652,
#          0.01756997, -0.03329592, -0.00027301, -0.03797637, -0.0412464 ],
#        [-0.02153742,  0.01453799, -0.03458333, -0.01842035,  0.04691168,
#         -0.00245248,  0.02281087, -0.02179828,  0.0454965 , -0.0057093 ],
#        [-0.0493977 , -0.048146  , -0.04539922,  0.01558084,  0.02030021,
#          0.0393564 ,  0.02715829,  0.04936004, -0.00837263,  0.03188236]],
#       dtype=float32)

# %%
model.predict(embedded_docs[0]).shape
# Out:
# 1/1 [==============================] - 0s 16ms/step
# (8, 10)
